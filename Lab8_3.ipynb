# %% [markdown]
# <a href="https://colab.research.google.com/github/PenugondaVyshnavi17/FMMLLABS/blob/main/Lab8_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-13 13:17:52--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   157MB/s    in 0.4s
#
# 2025-03-13 13:17:53 (157 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 36791   1411.6754v1  Nowadays, online clothes-selling business has ...    cs
# 29800  1710.06805v1  Despite the appeal of deep neural networks tha...    cs
# 37886   1102.2075v1  We study the scenario of graph-based clusterin...  stat
# 31444  1803.04108v4  Recent advances in facial landmark detection a...    cs
# 9510   1510.05613v2  In many robotic domains such as flexible autom...    cs
# ...             ...                                                ...   ...
# 9130   1503.08581v1  LSHTC is a series of challenges which aims to ...    cs
# 28917  1708.00370v2  A person's face discloses important informatio...    cs
# 12958   1310.2805v1  As a present to Mizar on its 40th anniversary,...    cs
# 12543  1802.08908v1  The rapid adoption of machine learning has inc...  stat
# 8587   1706.02337v1  We present an end-to-end, multimodal, fully co...    cs
#
#                                                    title  year  \
# 36791  HCRS: A hybrid clothes recommender system base...  2014
# 29800  Enhancing the Performance of Convolutional Neu...  2017
# 37886  How the result of graph clustering methods dep...  2011
# 31444  Style Aggregated Network for Facial Landmark D...  2018
# 9510   PERCH: Perception via Search for Multi-Object ...  2015
# ...                                                  ...   ...
# 9130   LSHTC: A Benchmark for Large-Scale Text Classi...  2015
# 28917  Hand2Face: Automatic Synthesis and Recognition...  2017
# 12958                              MizAR 40 for Mizar 40  2013
# 12543                Scalable Private Learning with PATE  2018
# 8587   Learning to Extract Semantic Structure from Do...  2017
#
#                                                 keywords
# 36791  [extremely, attractive, convenience, successfu...
# 29800  [traditional, convolutional, including, degrad...
# 37886  [clustering, algorithms, clustering, construct...
# 31444  [detection, discriminative, deformation, thems...
# 9510   [automated, manufacturing, assistance, fundame...
# ...                                                  ...
# 9130   [challenges, performance, classification, clas...
# 28917  [discloses, important, information, affective,...
# 12958  [anniversary, automatically, mathematical, con...
# 12543  [increased, implications, sensitive, informati...
# 8587   [multimodal, convolutional, extracting, struct...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 36791    [extremely, attractive, convenience, successfu...
# 29800    [traditional, convolutional, including, degrad...
# 37886    [clustering, algorithms, clustering, construct...
# 31444    [detection, discriminative, deformation, thems...
# 9510     [automated, manufacturing, assistance, fundame...
#                                ...
# 1838     [counterfactual, statistical, translation, tra...
# 10335    [stochastic, supervised, optimization, theoret...
# 19048    [selecting, preferred, probability, constraint...
# 6662     [contextual, literature, traditionally, algori...
# 37904    [statistical, selection, appropriate, complexi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8877 words.
# Out of those 4558 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4912773b-864d-4b94-a077-d88d9011391a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4912773b-864d-4b94-a077-d88d9011391a")) {                    Plotly.newPlot(                        "4912773b-864d-4b94-a077-d88d9011391a",                        [{"x":["extremely","thousands","attributes","recommend","recommender","experiments","convenience","attractive","successful","simulation","environment","challenge","collaborative","degradations","traditional","therefore","classification","investigation","enhancing","convolutional","performance","unexpected","surprising","including","generalized","complications","exhaustive","architecture","construction","convergence","geometric","different","construct","influences","normalized","partition","illustrate","parameters","objective","algorithm","algorithms","systematically","implications","clustering","demonstrated","robustness","detection","transforms","discriminative","benchmark","themselves","comparing","aggregated","intrinsic","adversarial","generative","increasing","detectors","inevitable","accompanying","complementary","available","grayscale","deformation","constantly","environmental","collected","overlooked","degenerate","identifying","explanation","fundamental","approaches","heuristic","localization","variations","hypothesized","recognition","localizing","successfully","canonical","exploiting","occlusion","assistance","tractable","manufacturing","automated","structure","leveraging","formulating","parallelization","generation","reasoning","optimization","perception","correspondences","descriptors","unreliable","contributions","combinatorial","experimental","extractor","development","principal","implement","equations","extraction","components","variational","assembling","discusses","impression","characters","description","researchers","character","frequency","discovery","applications","multitask","emphasize","dependent","validation","information","screening","guaranteed","industrial","additionally","suggesting","constructs","operators","framework","situations","axiomatic","discarded","inconsistency","discussed","completely","combining","epistemic","represented","priorities","semantics","reliability","relationship","conditional","incorporated","providing","presented","syntactically","sophisticated","strategies","semantically","simultaneously","introduction","demonstrate","involving","statistical","following","homomorphic","modelling","competitively","computational","preserving","encrypted","constraints","techniques","compromising","stochastic","estimator","cryptographic","parametric","constrained","adequately","metaheuristics","evaluates","constructive","engineering","competitive","metaheuristic","programming","formulate","distributions","sequential","allocation","independent","selection","optimality","approximately","approximate","generalizable","associated","asymptotic","approximation","computationally","possesses","efficient","minimization","important","dependency"],"y":[39,26,59,7,24,583,7,31,70,63,110,146,38,3,183,156,504,24,25,395,881,8,14,228,73,1,14,237,80,121,68,728,99,12,21,23,67,270,168,820,582,21,21,134,107,106,348,26,111,236,14,72,11,45,110,132,108,32,5,6,47,294,9,22,8,23,81,5,3,71,27,83,401,51,75,84,6,372,18,89,22,74,35,13,39,10,124,359,44,6,7,144,133,315,42,25,51,10,43,41,370,8,128,32,68,24,147,104,45,4,19,2,30,76,62,64,62,54,415,9,6,86,49,699,14,26,20,66,15,27,43,569,50,3,5,14,50,30,100,6,75,3,91,22,76,111,30,78,180,5,27,105,29,110,32,513,40,176,84,1,50,6,271,48,1,123,353,6,126,23,3,40,53,6,4,16,10,54,124,10,113,55,128,78,39,129,183,25,31,131,3,94,21,109,93,6,378,60,342,40],"type":"bar"},{"x":["extremely","thousands","attributes","recommend","recommender","expe ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4558,), (4558, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8133333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.6);'>Crossings</span> <span style=''>as</span> <span style=''>a</span> <span style=''>side</span> <span style=''>effect</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependency</span> <span style=''>lengths</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.9583333333333334);'>syntactic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.8787878787878788);'>sentences</span> <span style=''>exhibits</span> <span style=''>a</span> <span style=''>striking</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>regularity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependencies</span> <span style=''>tend</span> <span style=''>to</span> <span style=''>not</span> <span style=''>cross</span> <span style=''>when</span> <span style=''>drawn</span> <span style=''>above</span> <span style=''>the</span> <span style=''>sentence</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanations</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>traditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>is</span> <span style=''>that</span> <span style=''>this</span> <span style=''>trend</span> <span style=''>arises</span> <span style=''>from</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principle</span> <span style=''>of</span> <span style=''>syntax</span> <span style=''>that</span> <span style=''>reduces</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>crossings</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practically</span> <span style=''>to</span> <span style=''>zero</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>to</span> <span style=''>this</span> <span style=''>view</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>crossings</span> <span style=''>are</span> <span style=''>a</span> <span style=''>side</span> <span style=''>effect</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependency</span> <span style=''>lengths</span> <span style=''>ie</span> <span style='background-color:rgba(0, 255, 0, 0.8787878787878788);'>sentences</span> <span style=''>with</span> <span style=''>shorter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependency</span> <span style=''>lengths</span> <span style=''>should</span> <span style=''>tend</span> <span style=''>to</span> <span style=''>have</span> <span style=''>fewer</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>crossings</span> <span style=''>We</span> <span style=''>are</span> <span style=''>able</span> <span style=''>to</span> <span style=''>reject</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>traditional</span> <span style=''>view</span> <span style=''>in</span> <span style=''>the</span> <span style=''>majority</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.9428571428571428);'>languages</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considered</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>can</span> <span style=''>lead< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Automatic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Construction</span> <span style=''>and</span> <span style=''>Natural</span> <span style=''>Language</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Description</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <span style=''>Models</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>the</span> <span style=''>beginnings</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistician</span> <span style=''>focusing</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>problems</span> <span style=''>Our</span> <span style=''>system</span> <span style=''>explores</span> <span style=''>an</span> <span style=''>open</span> <span style=''>ended</span> <span style=''>space</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>models</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>a</span> <span style=''>good</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explanation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>data</span> <span style=''>set</span> <span style=''>and</span> <span style=''>then</span> <span style=''>produces</span> <span style=''>a</span> <span style=''>detailed</span> <span style=''>report</span> <span style=''>with</span> <span style=''>figures</span> <span style=''>and</span> <span style=''>natural</span> <span style=''>language</span> <span style=''>text</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>treats</span> <span style=''>unknown</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>nonparametrically</span> <span style=''>using</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>which</span> <span style=''>has</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consequences</span> <span style=''>First</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>can</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>high</span> <span style=''>level</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>(eg</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothness</span> <span style=''>trends</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>periodicity</span> <span style=''>changepoints)</span> <span style=''>Taken</span> <span style=''>together</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compositional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>our</span> <span style=''>language</span> <span style=''>of</span> <span style=''>models</span> <span style=''>this</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style=''>describe</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>in</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Message</span> <span style=''>passing</span> <span style=''>with</span> <span style=''>relaxed</span> <span style=''>moment</span> <span style=''>matching</span> <br/><br/><span style=''>Bayesian</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>often</span> <span style=''>hampered</span> <span style=''>by</span> <span style=''>large</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>expense</span> <span style=''>As</span> <span style=''>a</span> <span style=''>powerful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>popular</span> <span style=''>belief</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propagation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expectation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propagation</span> <span style=''>(EP)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(255, 0, 0, 0.4166666666666667);'>approximates</span> <span style=''>the</span> <span style=''>exact</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nevertheless</span> <span style=''>EP</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style=''>to</span> <span style=''>outliers</span> <span style=''>and</span> <span style=''>suffer</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.43902439024390255);'>divergence</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>cases</span> <span style=''>To</span> <span style=''>address</span> <span style=''>this</span> <span style=''>issue</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(255, 0, 0, 0.32137030995106036);'>inference</span> <span style=''>approach</span> <span style=''>relaxed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expectation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propagation</span> <span style=''>(REP)</span> <span style=''>It</span> <span style=''>relaxes</span> <span style=''>the</span> <span style=''>moment</span> <span style=''>matching</span> <span style='background-color:rgba(0, 255, 0, 0.3617021276595743);'>requirement</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expectation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propagation</span> <span style=''>by</span> <span style=''>adding</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.37254901960784326);'>relaxation</span> <span style=''>factor</span> <span style=''>into</span> <span style=''>the</span> <span style=''>KL</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>We</span> <span style=''>penalize</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.37254901960784326);'>relaxation</span> <span style=''>with</span> <span style=''>a</span> <span style=''>l</span> <span style=''>1</span> <span style=''>penalty</span> <span style=''>As</span> <span style=''>a</span> <span style=''>result</span> <span style=''>when</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>in</span> <span style=''>the</span> <span style=''>relaxed</span> <span style=''>KL</span> <span style='background-color:rgba(255, 0, 0, 0.43902439024390255);'>divergence</span> <span style=''>are</span> <span style=''>similar</span> <span style=''>the</span> <span style='bac ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Discovering</span> <span style=''>Causal</span> <span style=''>Signals</span> <span style=''>in</span> <span style=''>Images</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establishes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>existence</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observable</span> <span style=''>footprints</span> <span style=''>that</span> <span style=''>reveal</span> <span style=''>the</span> <span style=''>causal</span> <span style=''>dispositions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>object</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>categories</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>appearing</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collections</span> <span style=''>of</span> <span style=''>images</span> <span style=''>We</span> <span style=''>achieve</span> <span style=''>this</span> <span style=''>goal</span> <span style=''>in</span> <span style=''>two</span> <span style=''>steps</span> <span style=''>First</span> <span style=''>we</span> <span style=''>take</span> <span style=''>a</span> <span style=''>learning</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovery</span> <span style=''>and</span> <span style=''>build</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>that</span> <span style=''>achieves</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>finding</span> <span style=''>the</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>direction</span> <span style=''>between</span> <span style=''>pairs</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>given</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>their</span> <span style=''>joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>Second</span> <span style=''>we</span> <span style=''>use</span> <span style=''>our</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>direction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectively</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distinguish</span> <span style=''>between</span> <span style=''>features</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>and</span> <span style=''>features</span> <span style=''>of</span> <span style=''>their</span> <span style=''>contexts</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collections</span> <span style=''>of</span> <span style=''>static</span> <span style=''>images</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>relation</span> <span style=''>between</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>direction</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0 ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.09996429846483398)
# 	experimental (0.1320956801142449)
# 	architecture (0.08461263834344877)
# 	segmentation (0.06711888611210282)
# 	knowledge (0.12923955730096395)
# 	information (0.24955373081042484)
# 	different (0.2599071760085684)
# 	detection (0.12424134237772225)
# 	recognition (0.13280971081756515)
# 	convolutional (0.14102106390574795)
#
# Some Statistics words are:
# 	stochastic (0.12756378189094547)
# 	theoretical (0.1485742871435718)
# 	variables (0.144072036018009)
# 	statistical (0.15457728864432216)
# 	algorithm (0.38519259629814906)
# 	estimation (0.16908454227113556)
# 	distribution (0.1745872936468234)
# 	dimensional (0.192096048024012)
# 	inference (0.20260130065032517)
# 	regression (0.17958979489744872)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c6f174b6-0e99-4e5a-be58-efd20e4ed18a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6f174b6-0e99-4e5a-be58-efd20e4ed18a")) {                    Plotly.newPlot(                        "c6f174b6-0e99-4e5a-be58-efd20e4ed18a",                        [{"x":["extremely","thousands","attributes","recommend","recommender","experiments","convenience","attractive","successful","simulation","environment","challenge","collaborative","degradations","traditional","therefore","classification","investigation","enhancing","convolutional","performance","unexpected","surprising","including","generalized","complications","exhaustive","architecture","construction","convergence","geometric","different","construct","influences","normalized","partition","illustrate","parameters","objective","algorithm","algorithms","systematically","implications","clustering","demonstrated","robustness","detection","transforms","discriminative","benchmark","themselves","comparing","aggregated","intrinsic","adversarial","generative","increasing","detectors","inevitable","accompanying","complementary","available","grayscale","deformation","constantly","environmental","collected","overlooked","degenerate","identifying","explanation","fundamental","approaches","heuristic","localization","variations","hypothesized","recognition","localizing","successfully","canonical","exploiting","occlusion","assistance","tractable","manufacturing","automated","structure","leveraging","formulating","parallelization","generation","reasoning","optimization","perception","correspondences","descriptors","unreliable","contributions","combinatorial","experimental","extractor","development","principal","implement","equations","extraction","components","variational","assembling","discusses","impression","characters","description","researchers","character","frequency","discovery","applications","multitask","emphasize","dependent","validation","information","screening","guaranteed","industrial","additionally","suggesting","constructs","operators","framework","situations","axiomatic","discarded","inconsistency","discussed","completely","combining","epistemic","represented","priorities","semantics","reliability","relationship","conditional","incorporated","providing","presented","syntactically","sophisticated","strategies","semantically","simultaneously","introduction","demonstrate","involving","statistical","following","homomorphic","modelling","competitively","computational","preserving","encrypted","constraints","techniques","compromising","stochastic","estimator","cryptographic","parametric","constrained","adequately","metaheuristics","evaluates","constructive","engineering","competitive","metaheuristic","programming","formulate","distributions","sequential","allocation","independent","selection","optimality","approximately","approximate","generalizable","associated","asymptotic","approximation","computationally","possesses","efficient","minimization","important","dependency","crossings","syntactic","investigated","incorporating","determined","inference","integrating","conditions","identifiability","underlying","concerning","relationships","variables","acyclicity","randomized","observational","inferring","faithfulness","generating","knowledge","observing","assumption","scientific","statistics","overlapping","establish","phenomenon","sufficiency","intervening","intractability","intractable","computation","classical","probabilities","estimation","specifically","likelihood","expression","properties","virtually","deterministic","efficiency","estimators","pseudolikelihood","theoretical","covariance","desirable","prioritized","dimensional","specified","classifiers","introduced","concerned", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	faithfulness
# 	sufficiency
# 	subgroups
# 	contiguity
# 	martingale
# 	penalization
# 	forecaster
# 	elucidate
# 	subsampled
# 	resistance
# 	adaptiveness
# 	polyhedral
# 	multiplayer
# 	individualized
# 	certificate
# 	perceptible
# 	timestamp
# 	ingenious
# 	nonparametrics
# 	cubically
# Some words which never appear in Statistics papers:
# 	deformation
# 	localizing
# 	assembling
# 	discarded
# 	syntactically
# 	metaheuristics
# 	illumination
# 	realworld
# 	prerequisite
# 	affordances
# 	affordance
# 	hospitals
# 	originating
# 	formations
# 	legitimate
# 	supertagging
# 	observers
# 	ameliorate
# 	histories
# 	recognizes

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.070498648980594e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7716666666666666
